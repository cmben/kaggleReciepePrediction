# %%
import numpy as np
import scipy as sp
import nltk
import pandas as pd
import json

# %%
#Load the dataset
with open('../train.json', 'rU') as train_data_file:
    train_data = json.load(train_data_file)

# %%
train_data[0]['ingredients']
# Out:
# [u'romaine lettuce',
#  u'black olives',
#  u'grape tomatoes',
#  u'garlic',
#  u'pepper',
#  u'purple onion',
#  u'seasoning',
#  u'garbanzo beans',
#  u'feta cheese crumbles']

# %%
#Break train_data into features which are ingredients, labels which are cuisine and id.
train_words = []
train_labels = []
train_ids = []
for data in train_data:
    train_words.append(';'.join(data['ingredients']))
    train_labels.append(data['cuisine'])
    train_ids.append(data['id'])

# %%
train_words[1]
# Out:
# u'plain flour;ground pepper;salt;tomatoes;ground black pepper;thyme;eggs;green tomatoes;yellow corn meal;milk;vegetable oil'

# %%
from nltk.corpus import stopwords
import re
import string
#Function to clean the data
def clean_ingredients(raw_text):
    
    raw_text = filter(lambda x: x in string.printable, raw_text)
    
    #remove non letters
    letters_only = re.sub("[^a-zA-Z\;]"," ", raw_text)
    
    words = letters_only.lower().split(";")
    
    stops = set(stopwords.words("english"))
    meaningful_words = [w for w in words if not w in stops]
    
    clean_text =  ";".join(meaningful_words)
    return ' '.join(clean_text.split())

# %%
clean_ingredients("(    oz.) tomato sauce;(   oz.) tomato paste;1% low-fat buttermilk;a\xe7ai powder")
# Out:
# 'oz tomato sauce; oz tomato paste; low fat buttermilk;aai powder'

# %%
clean_train_words = []
for line in train_words:
    clean_train_words.append(clean_ingredients(line))

# %%
custom_tokenize = lambda x: x.split(';')
custom_tokenize(clean_train_words[1])
# Out:
# [u'plain flour',
#  u'ground pepper',
#  u'salt',
#  u'tomatoes',
#  u'ground black pepper',
#  u'thyme',
#  u'eggs',
#  u'green tomatoes',
#  u'yellow corn meal',
#  u'milk',
#  u'vegetable oil']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(tokenizer=custom_tokenize)

# %%
train_X = vec.fit_transform(clean_train_words)

# %%
train_X = train_X.toarray()

# %%
train_X.shape
# Out:
# (39774, 6696)

# %%
vocab = vec.get_feature_names()
vocab
# Out:
# [u' lean ground beef',
#  u' less sodium chicken broth',
#  u' less sodium ham',
#  u' less sodium taco seasoning',
#  u' less sodium taco seasoning mix',
#  u' low fat buttermilk',
#  u' low fat chocolate milk',
#  u' low fat cottage cheese',
#  u' low fat milk',
#  u' lowfat greek yogurt',
#  u' oz diced tomatoes',
#  u' oz frozen chopped spinach',
#  u' oz frozen chopped spinach thawed and squeezed dry',
#  u' oz refried beans',
#  u' oz sweetened condensed milk',
#  u' oz tomato paste',
#  u' oz tomato sauce',
#  u' reduced fat milk',
#  u' to lb chicken cut into serving pieces',
#  u' up',
#  u'aai',
#  u'aai powder',
#  u'abalone',
#  u'abura age',
#  u'accent',
#  u'accent seasoning',
#  u'achiote',
#  u'achiote paste',
#  u'achiote powder',
#  u'acini di pepe',
#  u'ackee',
#  u'acorn squash',
#  u'active dry yeast',
#  u'adobo',
#  u'adobo sauce',
#  u'adobo seasoning',
#  u'adzuki beans',
#  u'agar',
#  u'agave nectar',
#  u'aged balsamic vinegar',
#  u'aged cheddar cheese',
#  u'aged manchego cheese',
#  u'ahi',
#  u'ahi tuna steaks',
#  u'aioli',
#  u'ajinomoto',
#  u'ajwain',
#  u'aka miso',
#  u'alaskan king crab legs',
#  u'albacore',
#  u'albacore tuna in water',
#  u'alcohol',
#  u'ale',
#  u'aleppo pepper',
#  u'alfalfa sprouts',
#  u'alfredo sauce',
#  u'alfredo sauce mix',
#  u'all beef hot dogs',
#  u'all potato purpos',
#  u'all purpose flour',
#  u'all purpose seasoning',
#  u'all purpose unbleached flour',
#  u'allspice',
#  u'allspice berries',
#  u'almond butter',
#  u'almond extract',
#  u'almond filling',
#  u'almond flour',
#  u'almond liqueur',
#  u'almond meal',
#  u'almond milk',
#  u'almond paste',
#  u'almonds',
#  u'alphabet pasta',
#  u'alum',
#  u'amaranth',
#  u'amaretti',
#  u'amaretti cookies',
#  u'amaretto',
#  u'amaretto liqueur',
#  u'amber',
#  u'amchur',
#  u'american cheese',
#  u'american cheese food',
#  u'american cheese slices',
#  u'ammonium bicarbonate',
#  u'amontillado sherry',
#  u'ampalaya',
#  u'anaheim chile',
#  u'anasazi beans',
#  u'ancho',
#  u'ancho chile pepper',
#  u'ancho chili ground pepper',
#  u'ancho powder',
#  u'anchovies',
#  u'anchovy filets',
#  u'anchovy fillets',
#  u'anchovy paste',
#  u'and carrot green pea',
#  u'and fat free half half',
#  u'andouille chicken sausage',
#  u'andouille sausage',
#  u'andouille sausage links',
#  u'andouille turkey sausages',
#  u'angel food cake',
#  u'angel food cake mix',
#  u'angel hair',
#  u'angostura bitters',
#  u'anise',
#  u'anise extract',
#  u'anise oil',
#  u'anise powder',
#  u'anise seed',
#  u'anisette',
#  u'anjou pears',
#  u'annatto',
#  u'annatto powder',
#  u'annatto seeds',
#  u'aonori',
#  u'apple brandy',
#  u'apple butter',
#  u'apple cider',
#  u'apple cider vinegar',
#  u'apple jelly',
#  u'apple juice',
#  u'apple juice concentrate',
#  u'apple pie filling',
#  u'apple pie spice',
#  u'apple puree',
#  u'apple schnapps',
#  u'apple slice',
#  u'apples',
#  u'applesauce',
#  u'applewood smoked bacon',
#  u'apricot brandy',
#  u'apricot halves',
#  u'apricot jam',
#  u'apricot jelly',
#  u'apricot nectar',
#  u'apricot preserves',
#  u'apricots',
#  u'aquavit',
#  u'arak',
#  u'arbol chile',
#  u'arborio rice',
#  u'arepa flour',
#  u'argo corn starch',
#  u'arhar',
#  u'arhar dal',
#  u'armagnac',
#  u'arrow root',
#  u'arrowroot',
#  u'arrowroot flour',
#  u'arrowroot powder',
#  u'arrowroot starch',
#  u'artichok heart marin',
#  u'artichoke bottoms',
#  u'artichoke hearts',
#  u'artichokes',
#  u'arugula',
#  u'asadero',
#  u'asafetida',
#  u'asafetida powder',
#  u'asafetida powder ',
#  u'asafoetida',
#  u'asafoetida powder',
#  u'asiago',
#  u'asian barbecue sauce',
#  u'asian basil',
#  u'asian chile paste',
#  u'asian chili red sauc',
#  u'asian chili sauce',
#  u'asian eggplants',
#  u'asian fish sauce',
#  u'asian noodles',
#  u'asian pear',
#  u'asian rice noodles',
#  u'asian wheat noodles',
#  u'asparagus',
#  u'asparagus spears',
#  u'asparagus tips',
#  u'aspic',
#  u'assorted fresh vegetables',
#  u'atta',
#  u'au jus gravy mix',
#  u'au jus mix',
#  u'avocado',
#  u'avocado leaves',
#  u'avocado oil',
#  u'baby artichokes',
#  u'baby arugula',
#  u'baby back ribs',
#  u'baby bok choy',
#  u'baby broccoli',
#  u'baby carrots',
#  u'baby corn',
#  u'baby eggplants',
#  u'baby gem lettuce',
#  u'baby greens',
#  u'baby kale',
#  u'baby leaf lettuce',
#  u'baby lima beans',
#  u'baby portobello mushrooms',
#  u'baby potatoes',
#  u'baby radishes',
#  u'baby spinach',
#  u'baby spinach leaves',
#  u'baby tatsoi',
#  u'baby turnips',
#  u'baby zucchini',
#  u'bacardi',
#  u'back bacon',
#  u'back bacon rashers',
#  u'bacon',
#  u'bacon bits',
#  u'bacon crisp cooked and crumbled',
#  u'bacon drippings',
#  u'bacon fat',
#  u'bacon grease',
#  u'bacon pieces',
#  u'bacon salt',
#  u'bacon slices',
#  u'bagels',
#  u'baguette',
#  u'baileys irish cream liqueur',
#  u'baked beans',
#  u'baked ham',
#  u'baked pizza crust',
#  u'baked tortilla chips',
#  u'baking apples',
#  u'baking chocolate',
#  u'baking mix',
#  u'baking potatoes',
#  u'baking powder',
#  u'baking soda',
#  u'baking spray',
#  u'baking yeast',
#  u'balm',
#  u'balsamic reduction',
#  u'balsamic vinaigrette',
#  u'balsamic vinaigrette salad dressing',
#  u'balsamic vinegar',
#  u'balsamico bianco',
#  u'bamboo shoots',
#  u'banana blossom',
#  u'banana leaves',
#  u'banana liqueur',
#  u'banana peppers',
#  u'banana squash',
#  u'bananas',
#  u'banger',
#  u'banh pho rice noodles',
#  u'barbecue rub',
#  u'barbecue sauce',
#  u'barbecued pork',
#  u'barilla',
#  u'barilla oven ready lasagne',
#  u'barley',
#  u'barley flour',
#  u'barley miso',
#  u'barolo',
#  u'bartlett pear',
#  u'bartlett pears',
#  u'base',
#  u'basil',
#  u'basil dried leaves',
#  u'basil leaves',
#  u'basil mayonnaise',
#  u'basil pesto sauce',
#  u'basmati',
#  u'basmati rice',
#  u'bass fillets',
#  u'baton',
#  u'batter',
#  u'bawang goreng',
#  u'bay leaf',
#  u'bay leaves',
#  u'bay scallops',
#  u'bbq sauce',
#  u'bbq seasoning',
#  u'bean curd',
#  u'bean curd skins',
#  u'bean dip',
#  u'bean paste',
#  u'bean sauce',
#  u'bean soup',
#  u'bean soup mix',
#  u'bean thread vermicelli',
#  u'bean threads',
#  u'beans',
#  u'beansprouts',
#  u'beaten eggs',
#  u'beau monde seasoning',
#  u'beaujolais',
#  u'bechamel',
#  u'bee pollen',
#  u'beef',
#  u'beef base',
#  u'beef boneless meat stew',
#  u'beef bones',
#  u'beef bouillon',
#  u'beef bouillon granules',
#  u'beef bouillon powder',
#  u'beef brisket',
#  u'beef broth',
#  u'beef consomme',
#  u'beef deli roast slice thinli',
#  u'beef demi glace',
#  u'beef drippings',
#  u'beef fillet',
#  u'beef for stew',
#  u'beef gravy',
#  u'beef heart',
#  u'beef jerky',
#  u'beef kidney',
#  u'beef liver',
#  u'beef marrow',
#  u'beef rib roast',
#  u'beef rib short',
#  u'beef ribs',
#  u'beef roast',
#  u'beef round',
#  u'beef rump',
#  u'beef rump steaks',
#  u'beef sausage',
#  u'beef shank',
#  u'beef shoulder',
#  u'beef shoulder roast',
#  u'beef sirloin',
#  u'beef smoked sausage',
#  u'beef soup bones',
#  u'beef steak',
#  u'beef stew meat',
#  u'beef stock',
#  u'beef stock cubes',
#  u'beef tenderloin',
#  u'beef tenderloin steaks',
#  u'beef tendons',
#  u'beef tongue',
#  u'beefsteak tomatoes',
#  u'beer',
#  u'beet greens',
#  u'beets',
#  u'belgian endive',
#  u'bell pepper',
#  u'bengal gram',
#  u'bengali spice',
#  u'beni shoga',
#  u'berries',
#  u'bertolli alfredo sauce',
#  u'bertolli classico olive oil',
#  u'bertolli four chees rosa sauc',
#  u'bertolli garlic alfredo sauce',
#  u'bertolli vineyard premium collect marinara with burgundi wine sauc',
#  u'besan flour ',
#  u'best food s mayonnaise with lime juice',
#  u'best foods real mayonnaise',
#  u'beurre mani',
#  u'bhaji',
#  u'bhindi',
#  u'bibb lettuce',
#  u'bicarbonate of soda',
#  u'bihon',
#  u'bing cherries',
#  u'bird chile',
#  u'biryani masala',
#  u'biscotti',
#  u'biscuit baking mix',
#  u'biscuit dough',
#  u'biscuit mix',
#  u'biscuits',
#  u'bisquick',
#  u'bisquick baking mix',
#  u'bisquick original all purpose baking mix',
#  u'bitter gourd',
#  u'bitter melon',
#  u'bitters',
#  u'bittersweet baking chocolate',
#  u'bittersweet chocolate',
#  u'bittersweet chocolate chips',
#  u'black',
#  u'black bass',
#  u'black bean and corn salsa',
#  u'black bean garlic sauce',
#  u'black bean sauce',
#  u'black beans',
#  u'black cardamom pods',
#  u'black cod',
#  u'black cod fillets',
#  u'black cumin seeds',
#  u'black eyed peas',
#  u'black forest ham',
#  u'black fungus',
#  u'black gram',
#  u'black lentil',
#  u'black mission figs',
#  u'black moss',
#  u'black mustard seeds',
#  u'black olives',
#  u'black onion seeds',
#  u'black pepper',
#  u'black peppercorns',
#  u'black pudding',
#  u'black rice',
#  u'black rice vinegar',
#  u'black salt',
#  u'black sesame seeds',
#  u'black tea',
#  u'black tea leaves',
#  u'black treacle',
#  u'black truffle oil',
#  u'black truffles',
#  u'black trumpet mushrooms',
#  u'black turtle beans',
#  u'black vinegar',
#  u'black walnut',
#  u'blackberries',
#  u'blackberry jam',
#  u'blackening seasoning',
#  u'blackstrap molasses',
#  u'blade steak',
#  u'blanched almond flour',
#  u'blanched almonds',
#  u'blanched hazelnuts',
#  u'blanco tequila',
#  u'blood orange',
#  u'blood orange juice',
#  u'bloody mary mix',
#  u'blue cheese',
#  u'blue cheese dressing',
#  u'blue corn tortilla chips',
#  u'blue crabs',
#  u'blueberri preserv',
#  u'blueberries',
#  u'blueberry pie filling',
#  u'boar',
#  u'bocconcini',
#  u'boiled eggs',
#  u'boiled ham',
#  u'boiling onions',
#  u'boiling potatoes',
#  u'boiling water',
#  u'bok choy',
#  u'bolillo',
#  u'bologna',
#  u'bone broth',
#  u'bone in',
#  u'bone in chicken',
#  u'bone in chicken breast halves',
#  u'bone in chicken breasts',
#  u'bone in chicken thighs',
#  u'bone in pork chops',
#  u'bone in ribeye steak',
#  u'bone in short ribs',
#  u'bone in skin on chicken thigh',
#  u'bone in skinless chicken thigh',
#  u'bone marrow',
#  u'boned duck breast halves',
#  u'boned lamb shoulder',
#  u'boneless beef chuck roast',
#  u'boneless beef rib eye steaks',
#  u'boneless beef roast',
#  u'boneless beef short ribs',
#  u'boneless beef sirloin steak',
#  u'boneless center cut pork chops',
#  u'boneless chicken',
#  u'boneless chicken breast',
#  u'boneless chicken breast halves',
#  u'boneless chicken cutlet',
#  u'boneless chicken skinless thigh',
#  u'boneless chicken thigh fillets',
#  u'boneless chicken thighs',
#  u'boneless chop pork',
#  u'boneless chuck roast',
#  u'boneless country pork ribs',
#  u'boneless duck breast',
#  u'boneless ham',
#  u'boneless lamb',
#  u'boneless pork loin',
#  u'boneless pork shoulder',
#  u'boneless pork shoulder roast',
#  u'boneless rib eye steaks',
#  u'boneless salmon fillets',
#  u'boneless sirloin',
#  u'boneless sirloin steak',
#  u'boneless skin on chicken thighs',
#  u'boneless skinless chicken',
#  u'boneless skinless chicken breast',
#  u'boneless skinless chicken breast halves',
#  u'boneless skinless chicken breasts',
#  u'boneless turkey breast',
#  u'boneless veal shoulder',
#  u'bonito',
#  u'bonito flakes',
#  u'borage',
#  u'borlotti beans',
#  u'bosc pears',
#  u'boston butt',
#  u'boston lettuce',
#  u'bottle gourd',
#  u'bottled chili sauce',
#  u'bottled clam juice',
#  u'bottled italian dressing',
#  u'bottled lime juice',
#  u'bottom round',
#  u'bottom round roast',
#  u'boudin',
#  u'bouillon',
#  u'bouillon cube',
#  u'bouillon granules',
#  u'bouillon powder',
#  u'bouquet',
#  u'bouquet garni',
#  u'bourbon liqueur',
#  u'bourbon whiskey',
#  u'boursin',
#  u'bow tie pasta',
#  u'bows',
#  u'boysenberries',
#  u'braeburn apple',
#  u'bragg liquid aminos',
#  u'braggs liquid aminos',
#  u'braising steak',
#  u'brandy',
#  u'branzino',
#  u'brats',
#  u'brazil nuts',
#  u'bread',
#  u'bread and butter pickle slices',
#  u'bread and butter pickles',
#  u'bread ciabatta',
#  u'bread crumb fresh',
#  u'bread crumbs',
#  u'bread cut french into loaf',
#  u'bread cut into italian loaf',
#  u'bread dough',
#  u'bread flour',
#  u'bread machine yeast',
#  u'bread mix',
#  u'bread rolls',
#  u'bread slices',
#  u'breadfruit',
#  u'breadstick',
#  u'breakfast sausages',
#  u'breakstones sour cream',
#  u'breast',
#  u'breast of lamb',
#  u'breasts halves',
#  u'bresaola',
#  u'brewed coffee',
#  u'brewed espresso',
#  u'brewed tea',
#  u'breyers natural vanilla ice cream',
#  u'brie cheese',
#  u'brine',
#  u'brine cured black olives',
#  u'brine cured green olives',
#  u'brine cured olives',
#  u'brioche',
#  u'brioche bread',
#  u'brioche buns',
#  u'brisket',
#  u'broad beans',
#  u'broccoli',
#  u'broccoli florets',
#  u'broccoli rabe',
#  u'broccoli slaw',
#  u'broccoli stems',
#  u'broccolini',
#  u'broiler',
#  u'broiler fryer chicken',
#  u'broiler fryers',
#  u'broth',
#  u'brown ale',
#  u'brown basmati rice',
#  u'brown butter',
#  u'brown cardamom',
#  u'brown chicken stock',
#  u'brown gravy',
#  u'brown gravy mix',
#  u'brown hash potato',
#  u'brown lentils',
#  u'brown mushroom',
#  u'brown mustard',
#  u'brown mustard seeds',
#  u'brown rice',
#  u'brown rice flour',
#  u'brown rice noodles',
#  u'brown rice syrup',
#  u'brown rice vinegar',
#  u'brown shrimp',
#  u'brown sugar',
#  u'brownies',
#  u'browning',
#  u'brussels sprouts',
#  u'bucatini',
#  u'buckwheat',
#  u'buckwheat flour',
#  u'buckwheat groats',
#  u'buckwheat noodles',
#  u'buckwheat soba noodles',
#  u'buffalo',
#  u'buffalo mozarella',
#  u'buffalo mozzarella',
#  u'buffalo sauce',
#  u'bulb',
#  u'bulgur',
#  u'bulgur wheat',
#  u'bulk italian sausag',
#  u'buns',
#  u'burdock',
#  u'burger buns',
#  u'burgers',
#  u'burgundy',
#  u'burgundy wine',
#  u'burrata',
#  u'butter',
#  u'butter beans',
#  u'butter cooking spray',
#  u'butter crackers',
#  u'butter extract',
#  u'butter lettuce',
#  u'butter margarine blend',
#  u'butter oil',
#  u'butter pecan cake mix',
#  u'butter pecan ice cream',
#  u'buttercream frosting',
#  u'butterflied leg of lamb',
#  u'buttermilk',
#  u'buttermilk biscuits',
#  u'buttermilk cornbread',
#  u'butternut squash',
#  u'butterscotch chips',
#  u'butterscotch sauce',
#  u'button mushrooms',
#  u'cabbage',
#  u'cabbage leaves',
#  u'cabernet sauvignon',
#  u'cabrales',
#  u'cacao nibs',
#  u'cacao powder',
#  u'cachaca',
#  u'caciocavallo',
#  u'cactus pad',
#  u'cactus paddles',
#  u'caesar salad dressing',
#  u'cajeta',
#  u'cajun creole seasoning mix',
#  u'cajun seasoning',
#  u'cajun seasoning mix',
#  u'cajun spice mix',
#  u'cajun style stewed tomatoes',
#  u'cake',
#  u'cake batter',
#  u'cake flour',
#  u'cake mix',
#  u'cake yeast',
#  u'calabaza',
#  u'calamansi',
#  u'calamansi juice',
#  u'calamari',
#  u'calamata olives',
#  u'calf liver',
#  u'california avocado',
#  u'california bay leaves',
#  u'california chile',
#  u'calimyrna figs',
#  u'callaloo',
#  u'calvados',
#  u'camembert',
#  u'campanelle',
#  u'campari',
#  u'campbell s condensed cheddar cheese soup',
#  u'campbell s condensed cream of chicken soup',
#  u'campbell s condensed cream of mushroom soup',
#  u'campbell s condensed tomato soup',
#  u'canadian bacon',
#  u'candied cherries',
#  u'candied fruit',
#  u'candied ginger',
#  u'candied lemon peel',
#  u'candied orange peel',
#  u'candied peel',
#  u'candied pineapple',
#  u'candlenuts',
#  u'candy',
#  u'candy bar',
#  u'candy canes',
#  u'candy sprinkles',
#  u'cane sugar',
#  u'cane syrup',
#  u'cane vinegar',
#  u'canela',
#  u'canned beans',
#  u'canned beef broth',
#  u'canned black beans',
#  u'canned chicken broth',
#  u'canned chipotles',
#  u'canned chopped tomatoes',
#  u'canned coconut milk',
#  u'canned corn',
#  u'canned jalapeno peppers',
#  u'canned low sodium chicken broth',
#  u'canned snails',
#  u'canned tomatoes',
#  u'canned tuna',
#  u'cannellini beans',
#  u'cannelloni shells',
#  u'canning salt',
#  u'cannoli shells',
#  u'canola',
#  u'canola mayonnaise',
#  u'canola oil',
#  u'canola oil cooking spray',
#  u'cantal',
#  u'cantaloupe',
#  u'canton noodles',
#  u'capellini',
#  u'caper berries',
#  u'capers',
#  u'capicola',
#  u'capocollo',
#  u'capon',
#  u'capsicum',
#  u'carambola',
#  u'caramel ice cream',
#  u'caramel ice cream topping',
#  u'caramel sauce',
#  u'caramel topping',
#  u'caramels',
#  u'caraway seeds',
#  u'carbonated water',
#  u'cardamom',
#  u'cardamom pods',
#  u'cardamom seeds',
#  u'cardamon',
#  u'caribbean jerk seasoning',
#  u'carnaroli rice',
#  u'carnation',
#  u'carne asada',
#  u'carne seca',
#  u'carnitas',
#  u'carp',
#  u'carpaccio',
#  u'carrot sticks',
#  u'carrots',
#  u'cashew butter',
#  u'cashew chop unsalt',
#  u'cashew nuts',
#  u'casings',
#  u'cassava',
#  u'cassava meal',
#  u'cassia cinnamon',
#  u'castellane',
#  u'caster',
#  u'caster sugar',
#  u'catalina dressing',
#  u'catfish',
#  u'catfish fillets',
#  u'catsup',
#  u'caul fat',
#  u'cauliflower',
#  u'cauliflower florets',
#  u'cauliflower flowerets',
#  u'cava',
#  u'cavatappi',
#  u'cavatelli',
#  u'caviar',
#  u'cavolo nero',
#  u'cayenne',
#  u'cayenne pepper',
#  u'cayenne pepper sauce',
#  u'celery',
#  u'celery flakes',
#  u'celery heart',
#  u'celery leaves',
#  u'celery ribs',
#  u'celery root',
#  u'celery salt',
#  u'celery seed',
#  u'celery stick',
#  u'celtic salt',
#  u'center cut bacon',
#  u'center cut loin pork chop',
#  u'center cut pork chops',
#  u'center cut pork loin chops',
#  u'center cut salmon fillet',
#  u'century eggs',
#  u'cereal',
#  u'cereal flakes',
#  u'ceylon cinnamon',
#  u'chaat masala',
#  u'challa',
#  u'chambord',
#  u'chambord liqueur',
#  u'champagne',
#  u'champagne grapes',
#  u'champagne vinegar',
#  u'chana dal',
#  u'channa dal',
#  u'chanterelle',
#  u'chapati flour',
#  u'chapatti flour',
#  u'char',
#  u'char fillets',
#  u'char siu',
#  u'char siu sauce',
#  u'chard',
#  u'chardonnay',
#  u'chartreuse liqueur',
#  u'chat masala',
#  u'chateaubriand',
#  u'chayotes',
#  u'cheddar cheese',
#  u'cheddar cheese soup',
#  u'chees fresco queso',
#  u'chees fresh mozzarella',
#  u'chees mozzarella stick',
#  u'cheese',
#  u'cheese cubes',
#  u'cheese dip',
#  u'cheese ravioli',
#  u'cheese sauce',
#  u'cheese slices',
#  u'cheese soup',
#  u'cheese spread',
#  u'cheese sticks',
#  u'cheese tortellini',
#  u'chenpi',
#  u'cherries',
#  u'cherry gelatin',
#  u'cherry juice',
#  u'cherry peppers',
#  u'cherry pie filling',
#  u'cherry preserves',
#  u'cherry tomatoes',
#  u'cherrystone clams',
#  u'chervil',
#  u'chestnut mushrooms',
#  u'chestnut pure',
#  u'chestnut spread',
#  u'chestnuts',
#  u'chia seeds',
#  u'chianti',
#  u'chicharron',
#  u'chicken',
#  u'chicken and rice soup',
#  u'chicken apple sausage',
#  u'chicken base',
#  u'chicken bones',
#  u'chicken bouillon',
#  u'chicken bouillon granules',
#  u'chicken breast fillets',
#  u'chicken breast halves',
#  u'chicken breast strips',
#  u'chicken breast tenderloins',
#  u'chicken breast tenders',
#  u'chicken breasts',
#  u'chicken broth',
#  u'chicken broth low fat',
#  u'chicken carcass',
#  u'chicken cutlets',
#  u'chicken demi glace',
#  u'chicken drumsticks',
#  u'chicken feet',
#  u'chicken fillets',
#  u'chicken fingers',
#  u'chicken flavor stuffing mix',
#  u'chicken flavored soup powder',
#  u'chicken gizzards',
#  u'chicken gravy',
#  u'chicken gravy mix',
#  u'chicken leg quarters',
#  u'chicken legs',
#  u'chicken livers',
#  u'chicken meat',
#  u'chicken noodle soup',
#  u'chicken parts',
#  u'chicken pieces',
#  u'chicken sausage',
#  u'chicken schmaltz',
#  u'chicken soup base',
#  u'chicken stock',
#  u'chicken stock cubes',
#  u'chicken strips',
#  u'chicken tenderloin',
#  u'chicken thigh fillets',
#  u'chicken thighs',
#  u'chicken wing drummettes',
#  u'chicken wingettes',
#  u'chicken wings',
#  u'chickpea flour',
#  u'chickpeas',
#  u'chicory',
#  u'chiffonade',
#  u'chihuahua cheese',
#  u'chile bean paste',
#  u'chile de arbol',
#  u'chile negro',
#  u'chile paste',
#  u'chile paste with garlic',
#  u'chile pepper',
#  u'chile powder',
#  u'chile puree',
#  u'chile sauce',
#  u'chile verde',
#  u'chilean sea bass fillets',
#  u'chilegarlic sauce',
#  u'chiles',
#  u'chili',
#  u'chili bean paste',
#  u'chili bean sauce',
#  u'chili beans',
#  u'chili con carne',
#  u'chili flakes',
#  u'chili garlic paste',
#  u'chili habanero pepper',
#  u'chili oil',
#  u'chili paste',
#  u'chili paste with garlic',
#  u'chili pepper',
#  u'chili pepper flakes',
#  u'chili powder',
#  u'chili sauce',
#  u'chili seasoning',
#  u'chili seasoning mix',
#  u'chilled prosecco',
#  u'chilli bean sauce',
#  u'chilli paste',
#  u'chillies',
#  u'chinese barbecue sauce',
#  u'chinese black bean',
#  u'chinese black mushrooms',
#  u'chinese black vinegar',
#  u'chinese cabbage',
#  u'chinese celery',
#  u'chinese chili paste',
#  u'chinese chives',
#  u'chinese cinnamon',
#  u'chinese egg noodles',
#  u'chinese eggplants',
#  u'chinese five spice powder',
#  u'chinese ginger',
#  u'chinese ham',
#  u'chinese leaf',
#  u'chinese mustard',
#  u'chinese noodles',
#  u'chinese pancakes',
#  u'chinese parsley',
#  u'chinese plum sauce',
#  u'chinese red rice vinegar',
#  u'chinese rice vinegar',
#  u'chinese rice wine',
#  u'chinese roast pork',
#  u'chinese rock sugar',
#  u'chinese rose wine',
#  u'chinese sausage',
#  u'chinese sesame paste',
#  u'chinese spinach',
#  u'chinese turnip',
#  u'chinese wheat noodles',
#  u'chinkiang vinegar',
#  u'chip plain tortilla',
#  u'chipotle',
#  u'chipotle chile',
#  u'chipotle chile powder',
#  u'chipotle paste',
#  u'chipotle peppers',
#  u'chipotle puree',
#  u'chipotle salsa',
#  u'chipotle sauce',
#  u'chipotles in adobo',
#  u'chips',
#  u'chitterlings',
#  u'chives',
#  u'cho cho',
#  u'chocolate',
#  u'chocolate baking bar',
#  u'chocolate bars',
#  u'chocolate cake mix',
#  u'chocolate candy bars',
#  u'chocolate chips',
#  u'chocolate chunks',
#  u'chocolate covered coffee beans',
#  u'chocolate covered english toffee',
#  u'chocolate curls',
#  u'chocolate glaze',
#  u'chocolate hazelnut spread',
#  u'chocolate ice cream',
#  u'chocolate instant pudding',
#  u'chocolate morsels',
#  u'chocolate mousse',
#  u'chocolate sandwich cookies',
#  u'chocolate sauce',
#  u'chocolate shavings',
#  u'chocolate spread',
#  u'chocolate sprinkles',
#  u'chocolate syrup',
#  u'chocolate truffle',
#  u'chocolate wafer cookies',
#  ...]

# %%
set_labels = set(train_labels)
reverse_class_map = {w : i for w,i in enumerate(set_labels)}
class_map = {w : i for i, w in enumerate(set_labels)}

# %%
train_y = [class_map[c] for c in train_labels]

# %%
train_y[:10]
# Out:
# [9, 17, 3, 10, 10, 11, 13, 19, 1, 19]

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty='l2', alpha=1e-3, n_iter=10, random_state=42)
clf.fit(train_X, train_y)
# Out:
# SGDClassifier(alpha=0.001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=42, shuffle=True, verbose=0,
#        warm_start=False)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(train_X, train_y)

# %%
with open('../test.json') as test_data_file:
    test_data = json.load(test_data_file)

test_words = []
test_ids = []
for data in test_data:
    test_words.append(';'.join(data['ingredients']))
    test_ids.append(data['id'])

# %%
test_X = vec.transform(test_words)

# %%
test_X.shape
# Out:
# (9944, 6696)

# %%
test_y = clf.predict(test_X)

# %%
test_y_cuisine = [reverse_class_map[s] for s in test_y]

# %%
output = pd.DataFrame( data={"id":test_ids, "cuisine":test_y_cuisine} )
output.to_csv( "SGDClassifier1.csv", index=False )
